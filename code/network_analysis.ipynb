# %%
import networkx as nx 
import network_models as nm
import nx_tools as nxt
import pickle

# %%
with open('/Users/srutman/Library/CloudStorage/OneDrive-BowdoinCollege/Documents/DSAN6400/Dakar_networks/output/building_network_2016.pkl', 'rb') as f:
    G = pickle.load(f)

# Check what you got
print(type(G))          # Should be networkx.Graph, DiGraph, etc.
# Out:
# <class 'networkx.classes.graph.Graph'>

# %% [markdown]
# Compare to different known models

# %%
N = 500
p = .2
m = 2
a = .1

# %%
random = nm.gnp_random_graph(N,p,directed=False,output="graph")
print("done")
npa = nm.nonlinear_preferential_attachment(N,m,p,directed=False,output="graph")
print("done")
attract = nm.attractiveness(N,m, a,directed=False,output="graph")
print("done")
fitness = nm.fitness(N,m,directed=False,output="graph")
print("done")
random_walk = nm.random_walk(N,m,p,directed=False,output="graph")
print("done")
# Out:
# done
# done
# done
# done
# done

# %%
nxt.plot_degree_distribution(G, path="/Users/srutman/Library/CloudStorage/OneDrive-BowdoinCollege/Documents/DSAN6400/Dakar_networks/output/plots/degree_dist2016.png")

# %%
nxt.plot_centrality_correlation(G, path="/Users/srutman/Library/CloudStorage/OneDrive-BowdoinCollege/Documents/DSAN6400/Dakar_networks/output/plots/centrality2016.png")
nxt.plot_centrality_correlation(random, path="/Users/srutman/Library/CloudStorage/OneDrive-BowdoinCollege/Documents/DSAN6400/Dakar_networks/output/plots/centrality_random.png")
nxt.plot_centrality_correlation(npa, path="/Users/srutman/Library/CloudStorage/OneDrive-BowdoinCollege/Documents/DSAN6400/Dakar_networks/output/plots/centrality_npa.png")
nxt.plot_centrality_correlation(attract, path="/Users/srutman/Library/CloudStorage/OneDrive-BowdoinCollege/Documents/DSAN6400/Dakar_networks/output/plots/centrality_attract.png")
nxt.plot_centrality_correlation(fitness, path="/Users/srutman/Library/CloudStorage/OneDrive-BowdoinCollege/Documents/DSAN6400/Dakar_networks/output/plots/centrality_fitness.png")

# %%
print("2016")
nxt.network_summary(G)
print("random")
nxt.network_summary(random)
print("non preferential linear attachment")
nxt.network_summary(npa)
print("attractiveness")
nxt.network_summary(attract)
print("fitness")
nxt.network_summary(fitness)
# Out:
# 2016
# GENERAL
# 	number of nodes: 101789
# 	number of edges: 17967
# 	is_directed: False
# 	is_weighted: False
# 	number_connected_components 84622
# 	number of triangle:  101789
# 	density: 3.468231948741722e-06
# 	average_clustering coefficient:  0.008001187291925978
# 	degree_assortativity_coefficient:  0.21574780020598275
# 	is_tree: False
# DEGREE (NORMALIZED)
# 	min: 0.0
# 	mean: 3.468231948741722e-06
# 	median: 0.0
# 	max: 0.00015718945258773136
# 	top nodes: [38431, 77548, 50844, 27549, 36938, 38024]
# 	           [0.00015718945258773136, 0.00014736511180099814, 0.00013754077101426493, 0.00012771643022753174, 0.00012771643022753174, 0.00012771643022753174]
# CLOSENESS CENTRALITY
# 	min: 0.0
# 	mean: 5.606998920673699e-06
# 	median: 0.0
# 	max: 0.00022941163350641877
# 	top nodes: [20381, 50844, 19583, 38431, 38379, 48634]
# ...
